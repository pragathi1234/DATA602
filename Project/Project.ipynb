# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("Motor_Vehicle_Collisions_-_Crashes.csv",low_memory=False)

# %%
data.head()
# Out:
#    CRASH DATE CRASH TIME   BOROUGH ZIP CODE  LATITUDE  LONGITUDE  \
# 0  04/14/2021       5:32       NaN      NaN       NaN        NaN
# 1  04/13/2021      21:35  BROOKLYN    11217  40.68358  -73.97617
# 2  04/15/2021      16:15       NaN      NaN       NaN        NaN
# 3  04/13/2021      16:00  BROOKLYN    11222       NaN        NaN
# 4  04/12/2021       8:25       NaN      NaN   0.00000    0.00000
#
#                 LOCATION                    ON STREET NAME CROSS STREET NAME  \
# 0                    NaN           BRONX WHITESTONE BRIDGE               NaN
# 1  (40.68358, -73.97617)                               NaN               NaN
# 2                    NaN          HUTCHINSON RIVER PARKWAY               NaN
# 3                    NaN                 VANDERVORT AVENUE    ANTHONY STREET
# 4             (0.0, 0.0)  EDSON AVENUE                                   NaN
#
#                             OFF STREET NAME  ...  \
# 0                                       NaN  ...
# ...

# %%
data.shape
# Out:
# (1839610, 29)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1839610 entries, 0 to 1839609
# Data columns (total 29 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   CRASH DATE                     object
#  1   CRASH TIME                     object
#  2   BOROUGH                        object
#  3   ZIP CODE                       object
#  4   LATITUDE                       float64
#  5   LONGITUDE                      float64
#  6   LOCATION                       object
#  7   ON STREET NAME                 object
#  8   CROSS STREET NAME              object
#  9   OFF STREET NAME                object
#  10  NUMBER OF PERSONS INJURED      float64
#  11  NUMBER OF PERSONS KILLED       float64
#  12  NUMBER OF PEDESTRIANS INJURED  int64
#  13  NUMBER OF PEDESTRIANS KILLED   int64
#  14  NUMBER OF CYCLIST INJURED      int64
#  15  NUMBER OF CYCLIST KILLED       int64
#  16  NUMBER OF MOTORIST INJURED     int64
# ...

# %%
data.describe()
# Out:
#            LATITUDE     LONGITUDE  NUMBER OF PERSONS INJURED  \
# count  1.624587e+06  1.624587e+06               1.839592e+06
# mean   4.067250e+01 -7.383439e+01               2.817489e-01
# std    1.452459e+00  2.831036e+00               6.756955e-01
# min    0.000000e+00 -2.013600e+02               0.000000e+00
# 25%    4.066843e+01 -7.397559e+01               0.000000e+00
# 50%    4.072168e+01 -7.392800e+01               0.000000e+00
# 75%    4.076907e+01 -7.386669e+01               0.000000e+00
# max    4.334444e+01  0.000000e+00               4.300000e+01
#
#        NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# count              1.839579e+06                   1.839610e+06
# mean               1.319324e-03                   5.205560e-02
# std                3.833787e-02                   2.345516e-01
# min                0.000000e+00                   0.000000e+00
# 25%                0.000000e+00                   0.000000e+00
# ...

# %%
data.isnull().sum()
# Out:
# CRASH DATE                             0
# CRASH TIME                             0
# BOROUGH                           568230
# ZIP CODE                          568452
# LATITUDE                          215023
# LONGITUDE                         215023
# LOCATION                          215023
# ON STREET NAME                    375997
# CROSS STREET NAME                 661285
# OFF STREET NAME                  1555982
# NUMBER OF PERSONS INJURED             18
# NUMBER OF PERSONS KILLED              31
# NUMBER OF PEDESTRIANS INJURED          0
# NUMBER OF PEDESTRIANS KILLED           0
# NUMBER OF CYCLIST INJURED              0
# NUMBER OF CYCLIST KILLED               0
# NUMBER OF MOTORIST INJURED             0
# NUMBER OF MOTORIST KILLED              0
# CONTRIBUTING FACTOR VEHICLE 1       5310
# CONTRIBUTING FACTOR VEHICLE 2     266401
# CONTRIBUTING FACTOR VEHICLE 3    1713628
# CONTRIBUTING FACTOR VEHICLE 4    1812066
# CONTRIBUTING FACTOR VEHICLE 5    1832307
# ...

# %%
data.dtypes
# Out:
# CRASH DATE                        object
# CRASH TIME                        object
# BOROUGH                           object
# ZIP CODE                          object
# LATITUDE                         float64
# LONGITUDE                        float64
# LOCATION                          object
# ON STREET NAME                    object
# CROSS STREET NAME                 object
# OFF STREET NAME                   object
# NUMBER OF PERSONS INJURED        float64
# NUMBER OF PERSONS KILLED         float64
# NUMBER OF PEDESTRIANS INJURED      int64
# NUMBER OF PEDESTRIANS KILLED       int64
# NUMBER OF CYCLIST INJURED          int64
# NUMBER OF CYCLIST KILLED           int64
# NUMBER OF MOTORIST INJURED         int64
# NUMBER OF MOTORIST KILLED          int64
# CONTRIBUTING FACTOR VEHICLE 1     object
# CONTRIBUTING FACTOR VEHICLE 2     object
# CONTRIBUTING FACTOR VEHICLE 3     object
# CONTRIBUTING FACTOR VEHICLE 4     object
# CONTRIBUTING FACTOR VEHICLE 5     object
# ...

# %%
data['CRASH DATE']=pd.to_datetime(data['CRASH DATE'])
data['CRASH TIME']=pd.to_datetime(data['CRASH TIME'])
#data['date'] = pd.to_numeric(pd.to_datetime(data['date']))

# %%
data['BOROUGH'].unique()
# Out:
# array([nan, 'BROOKLYN', 'QUEENS', 'STATEN ISLAND', 'BRONX', 'MANHATTAN'],
#       dtype=object)

# %%
data['BOROUGH']=data['BOROUGH'].replace({"BROOKLYN":1,"QUEENS":2,"STATEN ISLAND":3,"BRONX":4,"MANHATTAN":5,"nan":6})

# %%
data.corr()
# Out:
#                                 BOROUGH  LATITUDE  LONGITUDE  \
# BOROUGH                        1.000000  0.037488  -0.008285
# LATITUDE                       0.037488  1.000000  -0.928091
# LONGITUDE                     -0.008285 -0.928091   1.000000
# NUMBER OF PERSONS INJURED     -0.056451 -0.003872   0.004646
# NUMBER OF PERSONS KILLED      -0.003802  0.000235  -0.000102
# NUMBER OF PEDESTRIANS INJURED  0.001699  0.000946  -0.000287
# NUMBER OF PEDESTRIANS KILLED  -0.000733 -0.000403   0.000445
# NUMBER OF CYCLIST INJURED     -0.001330 -0.003250   0.002419
# NUMBER OF CYCLIST KILLED      -0.000826  0.000321  -0.000345
# NUMBER OF MOTORIST INJURED    -0.061122 -0.003446   0.004229
# NUMBER OF MOTORIST KILLED     -0.004980  0.000657  -0.000480
# COLLISION_ID                  -0.051697 -0.024851   0.024134
#
#                                NUMBER OF PERSONS INJURED  \
# BOROUGH                                        -0.056451
# ...

# %%
data['BOROUGH'].unique()
# Out:
# array([nan,  1.,  2.,  3.,  4.,  5.])

# %%
data.hist(figsize=(13,10),bins=23)
plt.show()

# %%
sns.countplot(x='BOROUGH', data=data)
